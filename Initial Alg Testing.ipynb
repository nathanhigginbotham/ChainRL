# %% [markdown]
# # In this notebook I'm figuring out the final algorithms applicability (out of the box)

# %%
B

# %%
# Importing Required Modules
import gym
import numpy as np
import or_gym

import matplotlib.pyplot as plt
 
from tqdm import tqdm

# Importing PPO Algorithm and Base Policy

from stable_baselines3.common.evaluation import evaluate_policy

from sb3_contrib import RecurrentPPO
from sb3_contrib.ppo_recurrent.policies import RecurrentActorCriticPolicy

from sb3_contrib import ARS
from sb3_contrib.ars.policies import ARSPolicy


from sb3_contrib import TQC
from sb3_contrib.tqc.policies import MlpPolicy as TQCPolicy

# %%
###### 
# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model = TQC(TQCPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

mean_reward_before_train = evaluate_policy(model, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)
# Out:
# Mean reward: (-1518.743590260297, 3.925759022000168)

# %% [markdown]
# # TQC

# %%
EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model, env, n_eval_episodes=100)[0]

# %%
plt.plot(EpisodeNumber, mean_reward)

# %% [markdown]
# # ARS

# %%
###### ARS

# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model_ars = ARS(ARSPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

mean_reward_before_train = evaluate_policy(model_ars, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)


EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model_ars.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model_ars, env, n_eval_episodes=100)[0]


plt.plot(EpisodeNumber, mean_reward)
# Out:
# Mean reward: (9.671094661224634, 53.48456921445559)

# %% [markdown]
# # RECURRENT PPO

# %%
###### 

# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model_ppo = RecurrentPPO(RecurrentActorCriticPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

evaluate_policy(model_ppo, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)

EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model_ppo.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model_ppo, env, n_eval_episodes=100)[0]


plt.plot(EpisodeNumber, mean_reward)
# Out:
# Mean reward: (9.671094661224634, 53.48456921445559)

# %% [markdown]
# # TRPO

# %%
###### TRPO

from sb3_contrib import TRPO
from sb3_contrib.trpo.policies import MlpPolicy


# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model = TRPO(MlpPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

mean_reward_before_train = evaluate_policy(model, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)


EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model, env, n_eval_episodes=100)[0]


plt.plot(EpisodeNumber, mean_reward)
# Out:
# Mean reward: (-272.6168531809002, 4.465235376565707)

# %% [markdown]
# # DQN

# %%
###### TRPO

from stable_baselines3 import DQN
from stable_baselines3.dqn.policies import MlpPolicy


# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model = DQN(MlpPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

mean_reward_before_train = evaluate_policy(model, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)


EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model, env, n_eval_episodes=100)[0]


plt.plot(EpisodeNumber, mean_reward)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [27], line 11
#       8 env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')
#      10 # Constructing model
# ---> 11 model = DQN(MlpPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well
#      13 # Evaluating initial pre-training performance
#      15 mean_reward_before_train = evaluate_policy(model, env, n_eval_episodes=100)
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:97, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      70 def __init__(
#      71     self,
#      72     policy: Union[str, Type[DQNPolicy]],
#    (...)
#      95     _init_setup_model: bool = True,
#      96 ):
# ---> 97     super().__init__(
#      98         policy,
#      99         env,
#     100         learning_rate,
#     101         buffer_size,
#     102         learning_starts,
#     103         batch_size,
#     104         tau,
#     105         gamma,
#     106         train_freq,
#     107         gradient_steps,
#     108         action_noise=None,  # No action noise
#     109         replay_buffer_class=replay_buffer_class,
#     110         replay_buffer_kwargs=replay_buffer_kwargs,
#     111         policy_kwargs=policy_kwargs,
#     112         tensorboard_log=tensorboard_log,
#     113         verbose=verbose,
#     114         device=device,
#     115         seed=seed,
#     116         sde_support=False,
#     117         optimize_memory_usage=optimize_memory_usage,
#     118         supported_action_spaces=(spaces.Discrete,),
#     119         support_multi_env=True,
#     120     )
#     122     self.exploration_initial_eps = exploration_initial_eps
#     123     self.exploration_final_eps = exploration_final_eps
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:105, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      76 def __init__(
#      77     self,
#      78     policy: Union[str, Type[BasePolicy]],
#    (...)
#     103     supported_action_spaces: Optional[Tuple[spaces.Space, ...]] = None,
#     104 ):
# --> 105     super().__init__(
#     106         policy=policy,
#     107         env=env,
#     108         learning_rate=learning_rate,
#     109         policy_kwargs=policy_kwargs,
#     110         tensorboard_log=tensorboard_log,
#     111         verbose=verbose,
#     112         device=device,
#     113         support_multi_env=support_multi_env,
#     114         monitor_wrapper=monitor_wrapper,
#     115         seed=seed,
#     116         use_sde=use_sde,
#     117         sde_sample_freq=sde_sample_freq,
#     118         supported_action_spaces=supported_action_spaces,
#     119     )
#     120     self.buffer_size = buffer_size
#     121     self.batch_size = batch_size
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:168, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     165 self.env = env
#     167 if supported_action_spaces is not None:
# --> 168     assert isinstance(self.action_space, supported_action_spaces), (
#     169         f"The algorithm only supports {supported_action_spaces} as action spaces "
#     170         f"but {self.action_space} was provided"
#     171     )
#     173 if not support_multi_env and self.n_envs > 1:
#     174     raise ValueError(
#     175         "Error: the model does not support multiple envs; it requires " "a single vectorized environment."
#     176     )
#
# AssertionError: The algorithm only supports (<class 'gym.spaces.discrete.Discrete'>,) as action spaces but Box([0 0 0], [100  90  80], (3,), int16) was provided

# %% [markdown]
# # DDPG

# %%
###### TRPO

from stable_baselines3 import DDPG
from stable_baselines3.ddpg.policies import MlpPolicy


# Making Supply Chain Environment
env = or_gym.make('InvManagement-v1') #gym.make('CartPole-v1')

# Constructing model
model = DDPG(MlpPolicy, env, verbose=0) # I Tried MlpLstmPolicy as well

# Evaluating initial pre-training performance

mean_reward_before_train = evaluate_policy(model, env, n_eval_episodes=100)
print("Mean reward:", mean_reward_before_train)


EpisodeNumber = np.linspace(1000,50000,50)
mean_reward = np.zeros(50)

# Train the agent for 500,000 steps

for i in range(50):
    model.learn(total_timesteps=1000, progress_bar=False)
    mean_reward[i] = evaluate_policy(model, env, n_eval_episodes=100)[0]


plt.plot(EpisodeNumber, mean_reward)
# Out:
# Mean reward: (148.71672816541047, 23.217247545927894)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [26], line 25
#      22 # Train the agent for 500,000 steps
#      24 for i in range(50):
# ---> 25     model.learn(total_timesteps=1000, progress_bar=False)
#      26     mean_reward[i] = evaluate_policy(model, env, n_eval_episodes=100)[0]
#      29 plt.plot(EpisodeNumber, mean_reward)
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/ddpg/ddpg.py:123, in DDPG.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     114 def learn(
#     115     self: SelfDDPG,
#     116     total_timesteps: int,
#    (...)
#     121     progress_bar: bool = False,
#     122 ) -> SelfDDPG:
# --> 123     return super().learn(
#     124         total_timesteps=total_timesteps,
#     125         callback=callback,
#     126         log_interval=log_interval,
#     127         tb_log_name=tb_log_name,
#     128         reset_num_timesteps=reset_num_timesteps,
#     129         progress_bar=progress_bar,
#     130     )
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:211, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     202 def learn(
#     203     self: SelfTD3,
#     204     total_timesteps: int,
#    (...)
#     209     progress_bar: bool = False,
#     210 ) -> SelfTD3:
# --> 211     return super().learn(
#     212         total_timesteps=total_timesteps,
#     213         callback=callback,
#     214         log_interval=log_interval,
#     215         tb_log_name=tb_log_name,
#     216         reset_num_timesteps=reset_num_timesteps,
#     217         progress_bar=progress_bar,
#     218     )
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:351, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     349         # Special case when the user passes `gradient_steps=0`
#     350         if gradient_steps > 0:
# --> 351             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     353 callback.on_training_end()
#     355 return self
#
# File ~/miniforge3/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:159, in TD3.train(self, gradient_steps, batch_size)
#     155 replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)
#     157 with th.no_grad():
#     158     # Select action according to policy and add clipped noise
# --> 159     noise = replay_data.actions.clone().data.normal_(0, self.target_policy_noise)
#     160     noise = noise.clamp(-self.target_noise_clip, self.target_noise_clip)
#     161     next_actions = (self.actor_target(replay_data.next_observations) + noise).clamp(-1, 1)
#
# RuntimeError: "normal_kernel_cpu" not implemented for 'Short'
